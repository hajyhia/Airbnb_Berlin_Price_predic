# %% [markdown]
# <a href="https://colab.research.google.com/github/hajyhia/Airbnb_Berlin_Price_predic/blob/main/Airbnb_Berlin_Price_Pedict_Feature_Engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# from pandas_profiling import ProfileReport
import numpy as np
import missingno as msno
sns.set()
# plt.style.use('ggplot')
plt.style.use('seaborn-v0_8')
import warnings
import datetime as dt

from sklearn import ensemble, tree, linear_model
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

from scipy.stats import pearsonr
from scipy.stats import ks_2samp
from scipy.stats import norm
from scipy import stats
from scipy.stats import chisquare
from scipy.stats import chi2_contingency
from scipy.stats import f_oneway

# Ignore warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_Feature_Engineering = pd.read_pickle('/content/drive/My Drive/Airbnb/df_Feature_Engineering.pkl')

# %% [markdown]
# ## Declare data columns Lists

# %%
numerical_columns = ['Accomodates', 'Bathrooms', 'Bedrooms', 'Beds', 'Guests Included','Min Nights','Reviews','Price']
rating_columns = ['Value Rating','Location Rating', 'Cleanliness Rating','Checkin Rating','Accuracy Rating','Communication Rating','Host Response Rate','Overall Rating']
boolean_columns = ['Is Superhost','Is Exact Location', 'Instant Bookable']
categorical_columns = ['Room Type','Property Type Reduced','Neighborhood Group','Postal Code Reduced','Host Response Time'] # , 'Neighbourhood Grouped'
categorical_encoded_columns = ['Room Type Encoded','Property Type Reduced Encoded','Neighborhood Group Encoded','Postal Code Reduced Encoded','Host Response Time Encoded']
date_columns = ['review_date','Host Since']
geo_columns = ['Latitude','Longitude']
num_non_dummy_columns = numerical_columns + rating_columns + categorical_encoded_columns + geo_columns

# %%
df = df_Feature_Engineering.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23536 entries, 0 to 23535
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Accomodates            23536 non-null  float64
#  1   Accuracy Rating        23536 non-null  float64
#  2   Bathrooms              23536 non-null  float64
#  3   Bedrooms               23536 non-null  float64
#  4   Beds                   23536 non-null  float64
#  5   Checkin Rating         23536 non-null  float64
#  6   Cleanliness Rating     23536 non-null  float64
#  7   Communication Rating   23536 non-null  float64
#  8   Guests Included        23536 non-null  float64
#  9   Latitude               23536 non-null  float64
#  10  Location Rating        23536 non-null  float64
#  11  Longitude              23536 non-null  float64
#  12  Min Nights             23536 non-null  float64
#  13  Overall Rating         23536 non-null  float64
#  14  Price                  23536 non-null  float64
#  15  Reviews                23536 non-null  float64
#  16  Value Rating           23536 non-null  float64
#  17  Comments               23536 non-null  object
#  18  Host Response Time     23536 non-null  object
#  19  Is Superhost           23536 non-null  bool
#  20  neighbourhood          23536 non-null  object
#  21  Neighborhood Group     23536 non-null  object
#  22  Postal Code            23536 non-null  object
#  23  Is Exact Location      23536 non-null  bool
#  24  Property Type          23536 non-null  object
#  25  Room Type              23536 non-null  object
#  26  Instant Bookable       23536 non-null  bool
#  27  Property Type Reduced  23536 non-null  object
#  28  Postal Code Reduced    23536 non-null  object
# dtypes: bool(3), float64(17), object(9)
# memory usage: 4.7+ MB

# %%
df.isnull().sum()
# Out:
# Accomodates              0
# Accuracy Rating          0
# Bathrooms                0
# Bedrooms                 0
# Beds                     0
# Checkin Rating           0
# Cleanliness Rating       0
# Communication Rating     0
# Guests Included          0
# Latitude                 0
# Location Rating          0
# Longitude                0
# Min Nights               0
# Overall Rating           0
# Price                    0
# Reviews                  0
# Value Rating             0
# Comments                 0
# Host Response Time       0
# Is Superhost             0
# neighbourhood            0
# Neighborhood Group       0
# Postal Code              0
# Is Exact Location        0
# Property Type            0
# Room Type                0
# Instant Bookable         0
# Property Type Reduced    0
# Postal Code Reduced      0
# dtype: int64
