# %% [markdown]
# <a href="https://colab.research.google.com/github/hajyhia/Airbnb_Berlin_Price_predic/blob/main/Airbnb_Berlin_Feature_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install missingno
# !pip install geopy

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# from pandas_profiling import ProfileReport
import numpy as np
import missingno as msno
sns.set()
# plt.style.use('ggplot')
plt.style.use('seaborn-v0_8')
import warnings
import datetime as dt

from sklearn import ensemble, tree, linear_model
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

from scipy.stats import pearsonr
from scipy.stats import ks_2samp
from scipy.stats import norm
from scipy import stats
from scipy.stats import chisquare
from scipy.stats import chi2_contingency
from scipy.stats import f_oneway

# Ignore warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_Feature_Engineering = pd.read_pickle('/content/drive/My Drive/Airbnb/df_Feature_Engineering.pkl')

# %% [markdown]
# ## Declare data columns Lists

# %%
numerical_columns = ['Accomodates', 'Bathrooms', 'Bedrooms', 'Beds', 'Guests Included','Min Nights','Reviews','Price']
rating_columns = ['Value Rating','Location Rating', 'Cleanliness Rating','Checkin Rating','Accuracy Rating','Communication Rating','Host Response Rate','Overall Rating']
boolean_columns = ['Is Superhost','Is Exact Location', 'Instant Bookable']
categorical_columns = ['Room Type','Property Type Reduced','Neighborhood Group','Postal Code Reduced','Host Response Time'] # , 'Neighbourhood Grouped'
categorical_encoded_columns = ['Room Type Encoded','Property Type Reduced Encoded','Neighborhood Group Encoded','Postal Code Reduced Encoded','Host Response Time Encoded']
date_columns = ['review_date','Host Since']
geo_columns = ['Latitude','Longitude']
num_non_dummy_columns = numerical_columns + rating_columns + categorical_encoded_columns + geo_columns

# %% [markdown]
# # Feature Selection

# %%
df_Feature_Selection = pd.read_pickle('/content/drive/My Drive/Airbnb/df_Feature_Selection.pkl')
df_Feature_Selection.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23536 entries, 0 to 23535
# Data columns (total 34 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Accuracy Rating               23536 non-null  float64
#  1   Bathrooms                     23536 non-null  float64
#  2   Checkin Rating                23536 non-null  float64
#  3   Cleanliness Rating            23536 non-null  float64
#  4   Communication Rating          23536 non-null  float64
#  5   Latitude                      23536 non-null  float64
#  6   Location Rating               23536 non-null  float64
#  7   Longitude                     23536 non-null  float64
#  8   Overall Rating                23536 non-null  float64
#  9   Price                         23536 non-null  float64
#  10  Value Rating                  23536 non-null  float64
#  11  Comments                      23536 non-null  object
#  12  Host Since                    23515 non-null  datetime64[ns]
#  13  Host Response Time            23536 non-null  object
#  14  Is Superhost                  23536 non-null  bool
#  15  neighbourhood                 23536 non-null  object
#  16  Neighborhood Group            23536 non-null  object
#  17  Postal Code                   23536 non-null  object
#  18  Is Exact Location             23536 non-null  bool
#  19  Property Type                 23536 non-null  object
#  20  Room Type                     23536 non-null  object
#  21  Instant Bookable              23536 non-null  bool
#  22  Accomodates                   23536 non-null  float64
#  23  Bedrooms                      23536 non-null  float64
#  24  Beds                          23536 non-null  float64
#  25  Guests Included               23536 non-null  float64
#  26  Min Nights                    23536 non-null  float64
#  27  Reviews                       23536 non-null  float64
#  28  Property Type Reduced         23536 non-null  object
#  29  Postal Code Reduced           23536 non-null  object
#  30  Distance From Center          23536 non-null  float64
#  31  Distance From Center Reduced  23536 non-null  category
#  32  Host Since Year               23515 non-null  category
#  33  Host Since From Now           23536 non-null  int64
# dtypes: bool(3), category(2), datetime64[ns](1), float64(18), int64(1), object(9)
# memory usage: 5.3+ MB

# %%
df_Feature_Selection['Distance From Center Reduced']
# Out:
# 0         km_4
# 1         km_2
# 2         km_4
# 3         km_2
# 4         km_4
#          ...
# 23531    km_25
# 23532    km_25
# 23533     km_4
# 23534    km_25
# 23535     km_8
# Name: Distance From Center Reduced, Length: 23536, dtype: category
# Categories (9, object): ['km_0' < 'km_0.5' < 'km_1' < 'km_2' ... 'km_8' < 'km_10' < 'km_12' < 'km_25']

# %%
df = df_Feature_Selection.copy()

# %%
df = df.drop(columns=['Host Since','Host Since Year', 'Postal Code', 'Property Type', 'Comments','neighbourhood',
                      'Distance From Center', 'Longitude', 'Latitude'], inplace=False)

# %% [markdown]
# ## One-Hot Enciding and Label Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

df_object =  df.select_dtypes(include = ['object','category']).columns
for col in df_object:
  ord_enc = OrdinalEncoder()
  df[[col]] = ord_enc.fit_transform(df[[col]]).astype('int')

# %%
df.head(2)
# Out:
#    Accuracy Rating  Bathrooms  Checkin Rating  Cleanliness Rating  \
# 0             10.0        1.0            10.0                10.0
# 1              9.0        1.0             9.0                 9.0
#
#    Communication Rating  Location Rating  Overall Rating  Price  Value Rating  \
# 0                  10.0              9.0           100.0   17.0          10.0
# 1                   9.0             10.0            92.0   90.0           9.0
#
#    Host Response Time  Is Superhost  Neighborhood Group  Is Exact Location  \
# 0                   2         False                   6               True
# 1                   2         False                   6               True
#
#    Room Type  Instant Bookable  Accomodates  Bedrooms  Beds  Guests Included  \
# 0          1             False          2.0       1.0   1.0              1.0
# 1          0             False          4.0       1.0   2.0              2.0
#
#    Min Nights  Reviews  Property Type Reduced  Postal Code Reduced  \
# 0    2.000000      7.0                      0                    0
# 1    1.727273    144.0                      0                    0
#
#    Distance From Center Reduced  Host Since From Now
# 0                             7                   17
# 1                             5                   17

# %% [markdown]
# ## Multivariable Analysis

# %%
#Creating Variables dataframeS
varSel = pd.DataFrame({'Variable': df.columns.drop('Price')})
varSel
# Out:
#                         Variable
# 0                Accuracy Rating
# 1                      Bathrooms
# 2                 Checkin Rating
# 3             Cleanliness Rating
# 4           Communication Rating
# 5                Location Rating
# 6                 Overall Rating
# 7                   Value Rating
# 8             Host Response Time
# 9                   Is Superhost
# 10            Neighborhood Group
# 11             Is Exact Location
# 12                     Room Type
# 13              Instant Bookable
# 14                   Accomodates
# 15                      Bedrooms
# 16                          Beds
# 17               Guests Included
# 18                    Min Nights
# 19                       Reviews
# 20         Property Type Reduced
# 21           Postal Code Reduced
# 22  Distance From Center Reduced
# 23           Host Since From Now

# %%
df.to_csv('/content/drive/My Drive/Airbnb/df_Feature_Selection.csv')

# %%
nm = df.columns.drop('Price')
nm = nm.append(pd.Index(['Price']))
nm
# Out:
# Index(['Accuracy Rating', 'Bathrooms', 'Checkin Rating', 'Cleanliness Rating',
#        'Communication Rating', 'Location Rating', 'Overall Rating',
#        'Value Rating', 'Host Response Time', 'Is Superhost',
#        'Neighborhood Group', 'Is Exact Location', 'Room Type',
#        'Instant Bookable', 'Accomodates', 'Bedrooms', 'Beds',
#        'Guests Included', 'Min Nights', 'Reviews', 'Property Type Reduced',
#        'Postal Code Reduced', 'Distance From Center Reduced',
#        'Host Since From Now', 'Price'],
#       dtype='object')

# %%
df2 = df[nm].copy()

# %%
df2 = df2.dropna()
X = df.drop(columns='Price', inplace=False)
y = df['Price']

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVR
from sklearn.linear_model import Ridge

# %% [markdown]
# ### Variable Selection using LASSO (L1 penalization)

# %%
lassomod = Lasso(alpha=0.01).fit(X, y)
model = SelectFromModel(lassomod, prefit=True)
# print(f"get_support: {model.get_support()}")
# print(f"coef: {lassomod.coef_}")
varSel['Lasso'] = model.get_support().astype('int64')

# %% [markdown]
# ### Variable Selection using Ridge

# %%
ridge = Ridge(alpha=5).fit(X, y)
model = SelectFromModel(ridge, prefit=True)
# print(f"get_support: {model.get_support()}")
# print(f"coef: {ridge.coef_}")
varSel['Ridge'] = model.get_support().astype('int64')

# %%
alpha_values = np.logspace(-1, 1, 10)  # 10 values between 10^-4 and 10^4

# %%
alpha_values
# Out:
# array([ 0.1       ,  0.16681005,  0.27825594,  0.46415888,  0.77426368,
#         1.29154967,  2.15443469,  3.59381366,  5.9948425 , 10.        ])

# %%
from sklearn.linear_model import RidgeCV

# RidgeCV automatically finds the best alpha
ridge_cv = RidgeCV(alphas=alpha_values, store_cv_values=True)
ridge_cv.fit(X, y)

# Print the best alpha
print(f"Best alpha: {ridge_cv.alpha_}")
# Out:
# Best alpha: 10.0

# %% [markdown]
# ### Variable Selection using Gradient Boosting classification

# %%
gbmod = GradientBoostingRegressor().fit(X, y)
model = SelectFromModel(gbmod , prefit=True)
# print(f"get_support: {model.get_support()}")
# print(f"coef: {gbmod.coef_}")
varSel['GradientBoost'] = model.get_support().astype('int64')

# %% [markdown]
# ### Variable Selection using Random Forest

# %%
rfmod = RandomForestRegressor().fit(X, y)
model = SelectFromModel(rfmod, prefit=True)
# print(f"get_support: {model.get_support()}")
# print(f"coef: {rfmod.coef_}")
varSel['RandomForest'] = model.get_support().astype('int64')

# %% [markdown]
# ### Variable Selection using SVM classification

# %% [markdown]
# Commented out because it taked long time and never finish

# %%
# from sklearn.svm import LinearSVC, SVR
# from sklearn.feature_selection import SelectFromModel

# # svmmod = LinearSVC(C=0.01, penalty="l1",dual=False).fit(X, y)
# svmmod = SVR(kernel='linear').fit(X, y)
# model = SelectFromModel(svmmod, prefit=True)
# model.get_support()
# varSel['SVM'] = model.get_support().astype('int64')

# %% [markdown]
# ### Summarization and Selection of Variables

# %%
varSel['Sum'] = varSel[['Lasso', 'Ridge', 'GradientBoost','RandomForest']].sum(axis=1)
varSel
# Out:
#                         Variable  Lasso  Ridge  GradientBoost  RandomForest  \
# 0                Accuracy Rating      1      1              1             1
# 1                      Bathrooms      0      0              0             0
# 2                 Checkin Rating      1      1              0             1
# 3             Cleanliness Rating      1      0              1             1
# 4           Communication Rating      1      0              0             0
# 5                Location Rating      1      1              0             0
# 6                 Overall Rating      1      0              1             0
# 7                   Value Rating      1      0              0             0
# 8             Host Response Time      1      0              0             0
# 9                   Is Superhost      1      0              0             0
# 10            Neighborhood Group      1      0              0             1
# 11             Is Exact Location      1      1              0             0
# 12                     Room Type      1      1              0             0
# 13              Instant Bookable      1      1              0             0
# 14                   Accomodates      1      0              0             0
# 15                      Bedrooms      1      1              0             0
# 16                          Beds      1      0              0             0
# 17               Guests Included      1      1              0             0
# 18                    Min Nights      1      0              0             0
# 19                       Reviews      1      0              0             0
# 20         Property Type Reduced      1      1              1             1
# 21           Postal Code Reduced      1      0              0             0
# 22  Distance From Center Reduced      1      0              0             0
# 23           Host Since From Now      1      0              1             0
#
#     Sum
# 0     4
# 1     0
# 2     3
# 3     3
# 4     1
# 5     2
# 6     2
# 7     1
# 8     1
# 9     1
# 10    2
# 11    2
# 12    2
# 13    2
# 14    1
# 15    2
# 16    1
# 17    2
# 18    1
# 19    1
# 20    4
# 21    1
# 22    1
# 23    2

# %%
varSel.to_csv('/content/drive/My Drive/Airbnb/Feature_Selection_models.csv')

# %%
varSel.shape
# Out:
# (24, 6)

# %%
varSel[['Variable', 'Sum']].sort_values(by='Sum', ascending=False)
# Out:
#                         Variable  Sum
# 0                Accuracy Rating    4
# 20         Property Type Reduced    4
# 3             Cleanliness Rating    3
# 2                 Checkin Rating    3
# 6                 Overall Rating    2
# 13              Instant Bookable    2
# 11             Is Exact Location    2
# 5                Location Rating    2
# 15                      Bedrooms    2
# 23           Host Since From Now    2
# 17               Guests Included    2
# 10            Neighborhood Group    2
# 12                     Room Type    2
# 14                   Accomodates    1
# 4           Communication Rating    1
# 7                   Value Rating    1
# 19                       Reviews    1
# 8             Host Response Time    1
# 9                   Is Superhost    1
# 16                          Beds    1
# 21           Postal Code Reduced    1
# 18                    Min Nights    1
# 22  Distance From Center Reduced    1
# 1                      Bathrooms    0

# %%
varSel[varSel['Sum'] >=1].shape
# Out:
# (23, 6)

# %% [markdown]
# ## Multivariable Analysis

# %%
from sklearn.svm import LinearSVC

# Fit models and determine if a feature is selected (1) or not (0)
lasso = Lasso(alpha=5).fit(X, y)
lasso_selected = (np.abs(lasso.coef_) > 0).astype(int)

# Fit Ridge model
ridge = Ridge(alpha=5).fit(X, y)
ridge_selected = (np.abs(ridge.coef_) > 0).astype(int)

gb = GradientBoostingRegressor().fit(X, y)
gb_selected = (gb.feature_importances_ > 0).astype(int)

rf = RandomForestRegressor().fit(X, y)
rf_selected = (rf.feature_importances_ > 0).astype(int)

# Create a DataFrame to store results
selection_df = pd.DataFrame({
    'Feature': X.columns,
    'Lasso': lasso_selected,
    'GradientBoost': gb_selected,
    'RandomForest': rf_selected,
    'Ridge': ridge_selected
})

# Sum the number of selections for each feature
selection_df['Sum'] = selection_df[['Lasso', 'GradientBoost', 'RandomForest','Ridge']].sum(axis=1)

# Output the results
selection_df
# Out:
#                          Feature  Lasso  GradientBoost  RandomForest  Ridge  \
# 0                Accuracy Rating      1              1             1      1
# 1                      Bathrooms      0              0             0      0
# 2                 Checkin Rating      0              1             1      1
# 3             Cleanliness Rating      0              1             1      1
# 4           Communication Rating      0              1             1      1
# 5                Location Rating      0              1             1      1
# 6                 Overall Rating      1              1             1      1
# 7                   Value Rating      0              1             1      1
# 8             Host Response Time      1              1             1      1
# 9                   Is Superhost      0              1             1      1
# 10            Neighborhood Group      1              1             1      1
# 11             Is Exact Location      0              1             1      1
# 12                     Room Type      0              1             1      1
# 13              Instant Bookable      0              1             1      1
# 14                   Accomodates      1              1             1      1
# 15                      Bedrooms      1              1             1      1
# 16                          Beds      1              1             1      1
# 17               Guests Included      1              1             1      1
# 18                    Min Nights      1              1             1      1
# 19                       Reviews      1              1             1      1
# 20         Property Type Reduced      1              1             1      1
# 21           Postal Code Reduced      1              1             1      1
# 22  Distance From Center Reduced      0              1             1      1
# 23           Host Since From Now      1              1             1      1
#
#     Sum
# 0     4
# 1     0
# 2     3
# 3     3
# 4     3
# 5     3
# 6     4
# 7     3
# 8     4
# 9     3
# 10    4
# 11    3
# 12    3
# 13    3
# 14    4
# 15    4
# 16    4
# 17    4
# 18    4
# 19    4
# 20    4
# 21    4
# 22    3
# 23    4

# %%
selection_df.to_csv('/content/selection_variable_modele.csv')

# %%
selection_df.shape
# Out:
# (24, 6)

# %%
selection_df[['Feature', 'Sum']].sort_values(by='Sum', ascending=False)
# Out:
#                          Feature  Sum
# 0                Accuracy Rating    4
# 6                 Overall Rating    4
# 18                    Min Nights    4
# 19                       Reviews    4
# 15                      Bedrooms    4
# 14                   Accomodates    4
# 10            Neighborhood Group    4
# 8             Host Response Time    4
# 20         Property Type Reduced    4
# 21           Postal Code Reduced    4
# 23           Host Since From Now    4
# 16                          Beds    4
# 17               Guests Included    4
# 3             Cleanliness Rating    3
# 2                 Checkin Rating    3
# 5                Location Rating    3
# 12                     Room Type    3
# 7                   Value Rating    3
# 4           Communication Rating    3
# 11             Is Exact Location    3
# 9                   Is Superhost    3
# 13              Instant Bookable    3
# 22  Distance From Center Reduced    3
# 1                      Bathrooms    0

# %%
selection_df[selection_df['Sum'] >= 3].shape
# Out:
# (23, 6)

# %% [markdown]
# ### Creating DataFrame with most valuable variables

# %%
df
# Out:
#        Accuracy Rating  Bathrooms  Checkin Rating  Cleanliness Rating  \
# 0            10.000000        1.0       10.000000           10.000000
# 1             9.000000        1.0        9.000000            9.000000
# 2            10.000000        1.0       10.000000           10.000000
# 3            10.000000        1.0       10.000000           10.000000
# 4            10.000000        1.0        9.000000           10.000000
# ...                ...        ...             ...                 ...
# 23531         9.818182        1.0        9.818182            9.272727
# 23532         9.272727        1.0        9.636364            7.818182
# 23533        10.000000        1.0        9.636364            9.272727
# 23534         8.909091        1.0        9.818182            9.181818
# 23535         9.090909        1.0        8.909091            9.818182
#
#        Communication Rating  Location Rating  Overall Rating  Price  \
# 0                 10.000000         9.000000      100.000000   17.0
# 1                  9.000000        10.000000       92.000000   90.0
# 2                 10.000000        10.000000       96.000000   33.0
# 3                 10.000000        10.000000      100.000000  180.0
# 4                 10.000000         9.000000       93.000000   70.0
# ...                     ...              ...             ...    ...
# 23531              9.636364         9.454545       98.181818   48.0
# 23532              8.909091         8.727273       89.090909   30.0
# 23533              9.818182         9.272727      100.000000   17.0
# 23534              9.636364         9.181818       90.000000   52.0
# 23535              9.272727         9.272727       94.545455   65.0
#
#        Value Rating  Host Response Time  Is Superhost  Neighborhood Group  \
# 0         10.000000                   2         False                   6
# 1          9.000000                   2         False                   6
# 2         10.000000                   4          True                   6
# 3         10.000000                   2         False                   6
# 4          9.000000                   2         False                   6
# ...             ...                 ...           ...                 ...
# 23531      9.272727                   3         False                   9
# 23532      9.090909                   1         False                   6
# 23533      8.909091                   1         False                   5
# 23534      8.909091                   1         False                  11
# 23535      8.909091                   1         False                   6
#
#        Is Exact Location  Room Type  Instant Bookable  Accomodates  Bedrooms  \
# 0                   True          1             False     2.000000       1.0
# 1                   True          0             False     4.000000       1.0
# 2                   True          1             False     2.000000       1.0
# 3                  False          0             False     3.636364       4.0
# 4                   True          0             False     1.000000       0.0
# ...                  ...        ...               ...          ...       ...
# 23531              False          0              True     3.000000       1.0
# 23532               True          1              True     2.000000       2.0
# 23533               True          1              True     1.000000       1.0
# 23534               True          0              True     3.454545       3.0
# 23535              False          0              True     3.000000       2.0
#
#        Beds  Guests Included  Min Nights  Reviews  Property Type Reduced  \
# 0       1.0              1.0    2.000000      7.0                      0
# 1       2.0              2.0    1.727273    144.0                      0
# 2       2.0              1.0    2.000000    229.0                      0
# 3       7.0              5.0    6.000000      6.0                      0
# 4       1.0              1.0    2.454545     23.0                      0
# ...     ...              ...         ...      ...                    ...
# 23531   2.0              1.0    2.363636      0.0                      0
# 23532   2.0              2.0    5.000000      0.0                      0
# 23533   1.0              1.0    2.000000      0.0                      0
# 23534   4.0              1.0    2.000000      0.0                      0
# 23535   2.0              1.0    2.000000      0.0                      0
#
#        Postal Code Reduced  Distance From Center Reduced  Host Since From Now
# 0                        0                             7                   17
# 1                        0                             5                   17
# 2                        0                             7                   16
# 3                        0                             5                   16
# 4                        0                             7                   16
# ...                    ...                           ...                  ...
# 23531                    3                             6                    7
# 23532                    2                             6                    6
# 23533                    1                             7                   11
# 23534                    1                             6                    6
# 23535                    2                             8                    7
#
# [23536 rows x 25 columns]

# %% [markdown]
# ## Store state

# %%
selection_df.to_pickle("/content/drive/My Drive/Airbnb/feature_selection_df.pkl")
df.to_pickle("/content/drive/My Drive/Airbnb/df_Model_Selection.pkl")
