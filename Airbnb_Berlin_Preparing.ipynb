# %%
# !pip install missingno
# !pip install geopy

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings

# Ignore warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
AirbnbBerlin_df = pd.read_csv('/content/drive/My Drive/Airbnb/Airbnb Berlin.csv', index_col=0)

# %%
AirbnbBerlin_df.groupby(['Listing ID', 'Comments']).size().sort_values(ascending=False)
# Out:
# Listing ID  Comments
# 3838061     The host canceled this reservation 2 days before arrival. This is an automated posting.                                                                                                                                                                           5
# 14436882    The host canceled this reservation 2 days before arrival. This is an automated posting.                                                                                                                                                                           4
# 237038      nice stay                                                                                                                                                                                                                                                         4
# 3227823     The host canceled this reservation 2 days before arrival. This is an automated posting.                                                                                                                                                                           4
#             The host canceled this reservation the day before arrival. This is an automated posting.                                                                                                                                                                          4
#                                                                                                                                                                                                                                                                              ..
# 5158546     Ich habe meinen Aufenthalt in der hÃ¼bschen Pension von Dagmar sehr genossen! Sie hat meinen 3tÃ¤gigen Aufenthalt in Berlin noch einmal mehr zu etwas Besonderm gemacht. Die Zimmer sind hÃ¼bsch und nett "kitschig" eingerichtet. Das FrÃ¼hstÃ¼ck war extrem     1
#             I really enjoyed my stay in Dagmar' s pension, a lovely place decorated and very well furnished. It's a peaceful aera, very close to the tube. I apreciated the huge breakfast.                                                                                   1
#             I really enjoyed my 5 day stays at Dagmar's house.  It was a trip back in time with many thoughtful touches.  Breakfast's are exceptional, and the view onto the Rudesheimer Platz or out the back was lovely.  A home away from home that was very German in     1
#             I had the pleasure of staying in this wonderful place while visiting Berlin. Dagmar is a great host and communication is very pleasant. The house is located in a very nice neighbourbood with everything nearby. The French restaurant around the corner is s    1
# 34644792    The host canceled this reservation 12 days before arrival. This is an automated posting.                                                                                                                                                                          1
# Length: 452312, dtype: int64

# %%
df = AirbnbBerlin_df.copy()

# %% [markdown]
# # Data Preparation

# %%
# Display shape
df.shape
# Out:
# (456961, 46)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 456961 entries, 0 to 456960
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Review ID              452805 non-null  float64
#  1   review_date            452805 non-null  object
#  2   Reviewer ID            452805 non-null  float64
#  3   Reviewer Name          452805 non-null  object
#  4   Comments               452595 non-null  object
#  5   Listing ID             456961 non-null  int64
#  6   Listing URL            456961 non-null  object
#  7   Listing Name           456756 non-null  object
#  8   Host ID                456961 non-null  int64
#  9   Host URL               456961 non-null  object
#  10  Host Name              456913 non-null  object
#  11  Host Since             456913 non-null  object
#  12  Host Response Time     398194 non-null  object
#  13  Host Response Rate     398194 non-null  object
#  14  Is Superhost           456913 non-null  object
#  15  neighbourhood          456961 non-null  object
#  16  Neighborhood Group     456961 non-null  object
#  17  City                   456928 non-null  object
#  18  Postal Code            449258 non-null  object
#  19  Country Code           456961 non-null  object
#  20  Country                456961 non-null  object
#  21  Latitude               456961 non-null  float64
#  22  Longitude              456961 non-null  float64
#  23  Is Exact Location      456961 non-null  object
#  24  Property Type          456961 non-null  object
#  25  Room Type              456961 non-null  object
#  26  Accomodates            456961 non-null  int64
#  27  Bathrooms              456018 non-null  float64
#  28  Bedrooms               456244 non-null  float64
#  29  Beds                   456871 non-null  float64
#  30  Square Feet            28675 non-null   float64
#  31  Price                  456961 non-null  object
#  32  Guests Included        456961 non-null  int64
#  33  Min Nights             456961 non-null  int64
#  34  Reviews                456961 non-null  int64
#  35  First Review           452805 non-null  object
#  36  Last Review            452805 non-null  object
#  37  Overall Rating         452242 non-null  float64
#  38  Accuracy Rating        452209 non-null  float64
#  39  Cleanliness Rating     452211 non-null  float64
#  40  Checkin Rating         452188 non-null  float64
#  41  Communication Rating   452205 non-null  float64
#  42  Location Rating        452186 non-null  float64
#  43  Value Rating           452185 non-null  float64
#  44  Instant Bookable       456961 non-null  object
#  45  Business Travel Ready  456961 non-null  object
# dtypes: float64(15), int64(6), object(25)
# memory usage: 163.9+ MB

# %%
df.groupby('Listing ID').size().sort_values(ascending=False)
# Out:
# Listing ID
# 292864      545
# 517425      526
# 652366      496
# 127708      479
# 571751      459
#            ...
# 20069673      1
# 20071123      1
# 20081217      1
# 20081286      1
# 34682315      1
# Length: 23536, dtype: int64

# %% [markdown]
# Notice, 'Listing ID' is repeated in mutiple rows, which means that the data need to be aggregated by 'Listing ID'.
# Before aggregation we will Perform text cleaning, remove currency symbols & commas of some of clumns and clean and convert the numeric columns as was observed previously , which currently stored as an objects like 'Price' and 'Host Response Rate.

# %% [markdown]
# ## Aggregate dataset by Listing ID

# %% [markdown]
# Aggregate the dataset by 'Listing ID'
# - For numerical columns, we'll compute the mean
# - For categorical columns, we'll take the first/or last value (assuming consistency)
# - Clean text From pancutations or undesired characters

# %%
# Clean Text: Perform text cleaning, remove currency symbols & commas
df['Price'] = df['Price'].replace('[\$,]', '', regex=True).astype(float)
df['Host Response Rate'] = df['Host Response Rate'].replace('[\%,]', '', regex=True).astype(float)
df['Host Response Rate'] = df['Host Response Rate'].astype(float)

# Fix Postal Code incorrect values, remove '\n' and other irrelevant text
df['Postal Code'] = df['Postal Code'].astype(str).str[:5]

# %% [markdown]
# drop redundant columns

# %%
df = df.drop(columns=['Review ID', 'Reviewer ID', 'Reviewer Name', 'Listing URL','Listing Name', 'Host ID',
                      'Host URL', 'Host Name', 'City', 'Country Code', 'Country', 'Last Review', 'First Review',])

# %%
# Aggregate the dataset by 'Listing ID'
# For numerical columns, we'll compute the mean
# For categorical columns, we'll take the first value (assuming consistency)

categorical_cols = df.select_dtypes(include=['object']).columns
numerical_cols = df.select_dtypes(include=['number']).columns.difference(['Listing ID'])
aggregated_df = df.groupby('Listing ID').agg({**{col: 'mean' for col in numerical_cols},
                                              **{col: 'first' for col in categorical_cols}})

# aggregated_df = df.groupby('Listing ID').agg({**{col: 'mean' for col in numerical_cols},
#                                               **{col: lambda x: x.mode().iloc[0] if not x.mode().empty else None for col in categorical_cols}})

df = aggregated_df.reset_index()

# %% [markdown]
# ## Insepction

# %%
# Display shape
df.shape
# Out:
# (23536, 33)

# %%
# Display head(2) of remaining "df"
df.head(2)
# Out:
#    Listing ID  Accomodates  Accuracy Rating  Bathrooms  Bedrooms  Beds  \
# 0        2695          2.0             10.0        1.0       1.0   1.0
# 1        3176          4.0              9.0        1.0       1.0   2.0
#
#    Checkin Rating  Cleanliness Rating  Communication Rating  Guests Included  \
# 0            10.0                10.0                  10.0              1.0
# 1             9.0                 9.0                   9.0              2.0
#
#    Host Response Rate  Latitude  Location Rating  Longitude  Min Nights  \
# 0                50.0  52.54851              9.0   13.40455         2.0
# 1                50.0  52.53500             10.0   13.41758        62.0
#
#    Overall Rating  Price  Reviews  Square Feet  Value Rating review_date  \
# 0           100.0   17.0      7.0          NaN          10.0    07-04-18
# 1            92.0   90.0    144.0        720.0           9.0    06-20-09
#
#                                             Comments Host Since  \
# 0  I really enjoyed staying at Micha and Nadja's ...   09-16-08
# 1  excellent stay, i would highly recommend it. a...   10-19-08
#
#   Host Response Time Is Superhost    neighbourhood Neighborhood Group  \
# 0       within a day            f  Prenzlauer Berg             Pankow
# 1       within a day            f  Prenzlauer Berg             Pankow
#
#   Postal Code Is Exact Location Property Type        Room Type  \
# 0       10437                 t     Apartment     Private room
# 1       10405                 t     Apartment  Entire home/apt
#
#   Instant Bookable Business Travel Ready
# 0                f                     f
# 1                f                     f

# %% [markdown]
# On first sight, most features appear relatively informative and well-structured.
#
# Also, various numerical features are currently stored as objects and need to be transformed (e.g. Price, Host Response Rate, First Review, ...). Additionally, there are actually quite a few columns with missing values.
#
# I notice that reviewer's comments were stored as a string, which needs to be reviewed later on.
#
# At this point point, will move the comments column to a different dataset and store in sparated CSV file comments.csv

# %%
df_comments = df[['Listing ID', 'Comments']].copy()
df_comments.to_csv('/content/drive/My Drive/Airbnb/comments.csv')

# %% [markdown]
# Now we saved comment into different dataset, will drop it with other redundant columns

# %%
# df = df.drop(columns=['Comments'])

# %% [markdown]
# As expected, various numerical features are currently stored as objects and need to be transformed (e.g. Price, Host Response Rate, First Review, ...). Additionally, there are actually quite a few columns with missing values.

# %%
# categorical_cols
df.select_dtypes(include=['object']).columns
# Out:
# Index(['review_date', 'Comments', 'Host Since', 'Host Response Time',
#        'Is Superhost', 'neighbourhood', 'Neighborhood Group', 'Postal Code',
#        'Is Exact Location', 'Property Type', 'Room Type', 'Instant Bookable',
#        'Business Travel Ready'],
#       dtype='object')

# %% [markdown]
# As expected, various numerical features are currently stored as objects and need to be transformed (e.g. Price, Host Response Rate, First Review, ...). Additionally, there are actually quite a few columns with missing values.

# %%
# Describe data (summary)
df.describe().round(2).T
# Out:
#                         count         mean         std      min         25%  \
# Listing ID            23536.0  17782636.65  9887994.97  2695.00  9056046.25
# Accomodates           23536.0         2.67        1.57     1.00        2.00
# Accuracy Rating       18888.0         9.68        0.74     2.00       10.00
# Bathrooms             23507.0         1.10        0.35     0.00        1.00
# Bedrooms              23516.0         1.16        0.66     0.00        1.00
# Beds                  23501.0         1.64        1.23     0.00        1.00
# Checkin Rating        18870.0         9.73        0.70     2.00       10.00
# Cleanliness Rating    18892.0         9.33        1.03     2.00        9.00
# Communication Rating  18886.0         9.75        0.68     2.00       10.00
# Guests Included       23536.0         1.35        0.86     1.00        1.00
# Host Response Rate    13046.0        91.84       19.45     0.00       95.00
# Latitude              23536.0        52.51        0.03    52.35       52.49
# Location Rating       18871.0         9.55        0.75     2.00        9.00
# Longitude             23536.0        13.41        0.06    13.10       13.38
# Min Nights            23536.0         6.90       24.88     1.00        2.00
# Overall Rating        18914.0        94.56        7.60    20.00       92.00
# Price                 23536.0        69.61      216.66     0.00       32.00
# Reviews               23536.0        19.24       40.36     0.00        1.00
# Square Feet             425.0       487.13      517.65     0.00        0.00
# Value Rating          18868.0         9.42        0.84     2.00        9.00
#
#                               50%          75%          max
# Listing ID            18748175.00  25879867.00  34682315.00
# Accomodates                  2.00         3.00        16.00
# Accuracy Rating             10.00        10.00        10.00
# Bathrooms                    1.00         1.00         8.50
# Bedrooms                     1.00         1.00        10.00
# Beds                         1.00         2.00        22.00
# Checkin Rating              10.00        10.00        10.00
# Cleanliness Rating          10.00        10.00        10.00
# Communication Rating        10.00        10.00        10.00
# Guests Included              1.00         1.00        16.00
# Host Response Rate         100.00       100.00       100.00
# Latitude                    52.51        52.53        52.65
# Location Rating             10.00        10.00        10.00
# Longitude                   13.42        13.44        13.76
# Min Nights                   3.00         4.00      1000.00
# Overall Rating              97.00       100.00       100.00
# Price                       49.00        75.00      9000.00
# Reviews                      5.00        17.00       545.00
# Square Feet                420.00       753.00      4639.00
# Value Rating                10.00        10.00        10.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23536 entries, 0 to 23535
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Listing ID             23536 non-null  int64
#  1   Accomodates            23536 non-null  float64
#  2   Accuracy Rating        18888 non-null  float64
#  3   Bathrooms              23507 non-null  float64
#  4   Bedrooms               23516 non-null  float64
#  5   Beds                   23501 non-null  float64
#  6   Checkin Rating         18870 non-null  float64
#  7   Cleanliness Rating     18892 non-null  float64
#  8   Communication Rating   18886 non-null  float64
#  9   Guests Included        23536 non-null  float64
#  10  Host Response Rate     13046 non-null  float64
#  11  Latitude               23536 non-null  float64
#  12  Location Rating        18871 non-null  float64
#  13  Longitude              23536 non-null  float64
#  14  Min Nights             23536 non-null  float64
#  15  Overall Rating         18914 non-null  float64
#  16  Price                  23536 non-null  float64
#  17  Reviews                23536 non-null  float64
#  18  Square Feet            425 non-null    float64
#  19  Value Rating           18868 non-null  float64
#  20  review_date            19380 non-null  object
#  21  Comments               19378 non-null  object
#  22  Host Since             23515 non-null  object
#  23  Host Response Time     13046 non-null  object
#  24  Is Superhost           23515 non-null  object
#  25  neighbourhood          23536 non-null  object
#  26  Neighborhood Group     23536 non-null  object
#  27  Postal Code            23536 non-null  object
#  28  Is Exact Location      23536 non-null  object
#  29  Property Type          23536 non-null  object
#  30  Room Type              23536 non-null  object
#  31  Instant Bookable       23536 non-null  object
#  32  Business Travel Ready  23536 non-null  object
# dtypes: float64(19), int64(1), object(13)
# memory usage: 5.9+ MB

# %%
# Show maximum/minimum value for each numerical column
num_features = df.columns[df.dtypes!=object].difference(['Review ID', 'Reviewer ID', 'Listing ID', 'Host ID', 'Latitude', 'Longitude'])
df[num_features].describe().loc[['min','max']].T
# Out:
#                        min     max
# Accomodates            1.0    16.0
# Accuracy Rating        2.0    10.0
# Bathrooms              0.0     8.5
# Bedrooms               0.0    10.0
# Beds                   0.0    22.0
# Checkin Rating         2.0    10.0
# Cleanliness Rating     2.0    10.0
# Communication Rating   2.0    10.0
# Guests Included        1.0    16.0
# Host Response Rate     0.0   100.0
# Location Rating        2.0    10.0
# Min Nights             1.0  1000.0
# Overall Rating        20.0   100.0
# Price                  0.0  9000.0
# Reviews                0.0   545.0
# Square Feet            0.0  4639.0
# Value Rating           2.0    10.0

# %% [markdown]
# Several rows with unusually high values can be identified and may in some cases be dropped at a certain threshold during data handling and before aggrgation step. Some particular features include:

# %% [markdown]
# The description of price shows that 75% of the room only charged within 70€. But we can find the maximized price is extremely large - up to 9000€.
#
# To exclude the outlinear in this dataset, we set the data limit of 600€.
#
# It also shows that data has 0 price, that is not make sense. So we will exclude it too.

# %%
# df['Price'] = df['Price'].replace('[\$,]', '', regex=True).astype(float)
# df = df[(df['Price'] <= 600) & (df['Price'] > 0)]
# df['Price'].describe()

# %% [markdown]
# ## Features Selection (pre-cleaning)

# %% [markdown]
# 1. If a categorical column is not relevant to the analysis, we can remove it.
# 2. Listing URL, Listing Name, Host URL, Host Name: These are mostly unique to each listing, so not useful for category reduction
# 3. columns with 50% missing values will be dropped like 'Square Feet'

# %% [markdown]
# #### List missing values

# %%
# List missing values (pre-cleaning)
null_cols = df.columns[df.isnull().any(axis=0)] ## any columns with at lest one null value
df[null_cols].isna().sum().sort_values(ascending=False)
# Out:
# Square Feet             23111
# Host Response Rate      10490
# Host Response Time      10490
# Value Rating             4668
# Checkin Rating           4666
# Location Rating          4665
# Communication Rating     4650
# Accuracy Rating          4648
# Cleanliness Rating       4644
# Overall Rating           4622
# Comments                 4158
# review_date              4156
# Beds                       35
# Bathrooms                  29
# Host Since                 21
# Is Superhost               21
# Bedrooms                   20
# dtype: int64

# %% [markdown]
# Various features have a lot of missing values. In particular, there is an observable cut where many features have more than 4.500 missing values and the rest has less than 1.000. The former - except for review_scores - shall be removed, the latter imputed.

# %% [markdown]
# #### List unique entries

# %%
# List unique entries per column
df.nunique().sort_values(ascending=False)
# Out:
# Listing ID               23536
# Comments                 17600
# Longitude                14851
# Latitude                 11821
# Host Since                3085
# review_date               2382
# Reviews                    332
# Price                      326
# Postal Code                207
# Square Feet                109
# Min Nights                  97
# neighbourhood               93
# Host Response Rate          75
# Overall Rating              44
# Property Type               35
# Beds                        18
# Accomodates                 16
# Bathrooms                   16
# Guests Included             15
# Neighborhood Group          12
# Bedrooms                    11
# Cleanliness Rating           9
# Value Rating                 9
# Accuracy Rating              9
# Communication Rating         8
# Checkin Rating               8
# Location Rating              8
# Host Response Time           4
# Room Type                    3
# Is Superhost                 2
# Is Exact Location            2
# Instant Bookable             2
# Business Travel Ready        1
# dtype: int64

# %% [markdown]
# Three main insights from unique values:
#
# - Some columns have only 1 value and can be dropped
# - Some other columns have 2 values and appear to be true/false (i.e. can be recoded as 1/0)
# - Certain columns have a high number of unique values, which can probably be clustered into a few relevant ones (e.g. cancellation_policy, property_type)

# %% [markdown]
# #### Conclusions (selection) - dropping redundant columns

# %% [markdown]
# 1. If a categorical column is not relevant to the analysis, we can remove it.
# 2. Listing URL, Listing Name, Host URL, Host Name: These are mostly unique to each listing, so not useful for category reduction
# 3. columns with more than 50% missing values will be dropped like 'Square Feet'
# 4. 'Comment' columns can be dropped as it was stored in separated dataset
# 5. 'Business Travel Ready' has one value and can be dropped

# %%
# drop the columns that is not helpful for prediction
df = df.drop(columns=['Square Feet', 'Business Travel Ready'])

# %% [markdown]
# ## Reduce Large Categories

# %% [markdown]
# 1. Group Rare Categories: If a categorical column has many unique values, we can group infrequent categories into an "Other" category like 'Reviewer Name'.
# 2. Merge Similar Categories: If there are similar categories (e.g., different spellings or formats of the same category), we can merge them.
# 3. Binning: For numerical categories (like "Overall Rating" or "Accommodates"), we can create bins to reduce the number of unique values.

# %%
# # Fix Postal Code incorrect values, remove '\n' and other irrelevant text
# df['Postal Code'] = df['Postal Code'].astype(str).str[:5]

# 1. Clean Text: Perform text cleaning, remove currency symbols & commas
df['Price'] = df['Price'].replace('[\$,]', '', regex=True).astype(float)
df['Host Response Rate'] = df['Host Response Rate'].replace('[\%,]', '', regex=True).astype(float)
df['Host Response Rate'] = df['Host Response Rate'].astype(float)

# 2. Grouping neighbourhoods into Neighborhood Groups
if 'Neighborhood Group' in df.columns:
  neighbourhood_mapping = df.groupby('neighbourhood')['Neighborhood Group'].first()
  df['Neighbourhood Grouped'] = df['neighbourhood'].map(neighbourhood_mapping)

# 3. Reducing Property Types
property_mapping = {
    "Villa": "Vacation Rental",
    "Cottage": "Vacation Rental",
    "Bungalow": "Vacation Rental",
    "Cabin": "Vacation Rental",
    "Tiny house": "Vacation Rental",
    "Earth house": "Vacation Rental",
    "Treehouse": "Vacation Rental",
    "Hut": "Vacation Rental",
    "Barn": "Vacation Rental",
    "Houseboat": "Boats & Houseboats",
    "Boat": "Boats & Houseboats",
    "Camper/RV": "Mobile/Alternative Lodging",
    "Cave": "Mobile/Alternative Lodging",
    "Pension (South Korea)": "Mobile/Alternative Lodging",
    "Casa particular (Cuba)": "Mobile/Alternative Lodging",
}

# Apply mapping and assign 'Other' to rare categories
top_property_types = [
    "Apartment", "Loft", "House", "Townhouse", "Condominium", "Serviced apartment",
    "Hotel", "Hostel", "Guesthouse", "Bed and breakfast", "Boutique hotel"
]

df['Property Type Reduced'] = df['Property Type'].apply(
    lambda x: property_mapping.get(x, x) if x in top_property_types or x in property_mapping else "Other"
)

# 4. Binning Postal Codes (first two digits represent broad area)
df['Postal Code Reduced'] = df[df['Postal Code'].notna()]['Postal Code'].astype(str).str[:2]

# %% [markdown]
# ## Transform/Manipulate data

# %%
# Extracting years from date columns -- will be moved to data proccessing stage
# df['Host Since'] = pd.to_datetime(df['Host Since'])
# df['Host Since Year'] = df['Host Since'].dt.year.astype('str').apply(lambda x: (x.split('.')[0]))
# df['Host Since Year'] = df['Host Since Year'].apply(lambda x: None if x == 'nan' else x).astype('category')

# df['Host Since Month'] = df['Host Since'].dt.month.astype('str').apply(lambda x: (x.split('.')[0]))
# df['Host Since Month'] = df['Host Since Month'].apply(lambda x: None if x == 'nan' else x).astype('category')

# df['Host Since Day'] = df['Host Since'].dt.day.astype('str').apply(lambda x: (x.split('.')[0]))
# df['Host Since Day'] = df['Host Since Day'].apply(lambda x: None if x == 'nan' else x).astype('category')

# 5. transform true/false into bool
df['Instant Bookable'] = df['Instant Bookable'].replace({'t': True, 'f': False})
df['Is Exact Location'] = df['Is Exact Location'].replace({'t': True, 'f': False})
df['Is Superhost'] = df['Is Superhost'].replace({'t': True, 'f': False})
df['Is Superhost'] = df['Is Superhost'].astype(bool)

# %% [markdown]
# ## Pre-EDA (Exploratory Data Analysis)

# %% [markdown]
# Clean and drop redundant and duplicated columns before EDA

# %%
# https://public.opendatasoft.com/api/explore/v2.1/catalog/datasets/georef-germany-postleitzahl/records?limit=20&refine=lan_name%3A%22Berlin%22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23536 entries, 0 to 23535
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Listing ID             23536 non-null  int64
#  1   Accomodates            23536 non-null  float64
#  2   Accuracy Rating        18888 non-null  float64
#  3   Bathrooms              23507 non-null  float64
#  4   Bedrooms               23516 non-null  float64
#  5   Beds                   23501 non-null  float64
#  6   Checkin Rating         18870 non-null  float64
#  7   Cleanliness Rating     18892 non-null  float64
#  8   Communication Rating   18886 non-null  float64
#  9   Guests Included        23536 non-null  float64
#  10  Host Response Rate     13046 non-null  float64
#  11  Latitude               23536 non-null  float64
#  12  Location Rating        18871 non-null  float64
#  13  Longitude              23536 non-null  float64
#  14  Min Nights             23536 non-null  float64
#  15  Overall Rating         18914 non-null  float64
#  16  Price                  23536 non-null  float64
#  17  Reviews                23536 non-null  float64
#  18  Value Rating           18868 non-null  float64
#  19  review_date            19380 non-null  object
#  20  Comments               19378 non-null  object
#  21  Host Since             23515 non-null  object
#  22  Host Response Time     13046 non-null  object
#  23  Is Superhost           23536 non-null  bool
#  24  neighbourhood          23536 non-null  object
#  25  Neighborhood Group     23536 non-null  object
#  26  Postal Code            23536 non-null  object
#  27  Is Exact Location      23536 non-null  bool
#  28  Property Type          23536 non-null  object
#  29  Room Type              23536 non-null  object
#  30  Instant Bookable       23536 non-null  bool
#  31  Neighbourhood Grouped  23536 non-null  object
#  32  Property Type Reduced  23536 non-null  object
#  33  Postal Code Reduced    23536 non-null  object
# dtypes: bool(3), float64(18), int64(1), object(12)
# memory usage: 5.6+ MB

# %%
df_EDA = df.copy()
df_EDA.to_pickle("/content/drive/My Drive/Airbnb/df_EDA.pkl")
df_EDA.to_csv("/content/drive/My Drive/Airbnb/df_EDA.csv")

# %%
# cleaned_df = pd.read_pickle('/content/drive/My Drive/Airbnb/df_EDA.pkl')
# cleaned_df.info()
